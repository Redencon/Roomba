# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas, plotly, and dash.

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc

# %% [markdown]
# # Load and Inspect Data
# Load the events.csv file and inspect the data to understand its structure.

# %%
# Load and Inspect Data

# Load the events.csv file into a DataFrame
events_df = pd.read_csv('events.csv')

# Display the first few rows of the DataFrame to inspect the data
events_df.head()

# Display the summary statistics of the DataFrame
events_df.describe()

# Display the information about the DataFrame including data types and non-null counts
events_df.info()

# %% [markdown]
# # Preprocess Data
# Preprocess the data to convert time columns to datetime objects and filter data for the selected day.

# %%
# Convert 'start_time' and 'end_time' columns to datetime objects
events_df['start_time'] = pd.to_datetime(events_df['start_time'])
events_df['end_time'] = pd.to_datetime(events_df['end_time'])

# Function to filter data for the selected day
def filter_data_for_day(df, selected_date):
    # Convert selected_date to datetime
    selected_date = pd.to_datetime(selected_date)
    # Filter the DataFrame for the selected day
    filtered_df = df[(df['start_time'].dt.date == selected_date.date()) | (df['end_time'].dt.date == selected_date.date())]
    return filtered_df

# Example usage: Filter data for a specific date (e.g., '2023-10-01')
selected_date = '2023-10-01'
filtered_events_df = filter_data_for_day(events_df, selected_date)

# Display the filtered DataFrame
filtered_events_df.head()

# %% [markdown]
# # Create Date Picker
# Create a date picker component using Dash to allow users to select a date.

# %%
# Create Date Picker

# Create a Dash app instance
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Define the layout of the app
app.layout = html.Div([
    # Date Picker component
    dcc.DatePickerSingle(
        id='date-picker',
        date=pd.to_datetime('today').date(),  # Default to today's date
        display_format='YYYY-MM-DD'
    ),
    # Div to display the selected date
    html.Div(id='output-container-date-picker')
])

# Callback to update the output based on the selected date
@app.callback(
    Output('output-container-date-picker', 'children'),
    Input('date-picker', 'date')
)
def update_output(date):
    return f'Selected Date: {date}'

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # Generate Gantt Chart
# Use Plotly to generate a Gantt chart that shows room availability, grouping rooms by buildings and floors.

# %%
# Generate Gantt Chart

import plotly.express as px

# Function to generate Gantt chart
def generate_gantt_chart(df):
    fig = px.timeline(
        df,
        x_start="start_time",
        x_end="end_time",
        y="room",
        color="name",
        title="Room Availability",
        labels={"name": "Event Name"},
        category_orders={"room": sorted(df["room"].unique())}
    )
    fig.update_yaxes(categoryorder="total ascending")
    fig.update_layout(
        xaxis_title="Time",
        yaxis_title="Room",
        showlegend=True
    )
    return fig

# Example usage: Generate Gantt chart for the filtered events DataFrame
gantt_chart = generate_gantt_chart(filtered_events_df)
gantt_chart.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 26
#      23     return fig
#      25 # Example usage: Generate Gantt chart for the filtered events DataFrame
# ---> 26 gantt_chart = generate_gantt_chart(filtered_events_df)
#      27 gantt_chart.show()
#
# NameError: name 'filtered_events_df' is not defined

# %% [markdown]
# # Display Gantt Chart
# Display the Gantt chart on the Dash app.

# %%
# Display Gantt Chart

# Update the layout of the app to include the Gantt chart
app.layout = html.Div([
    # Date Picker component
    dcc.DatePickerSingle(
        id='date-picker',
        date=pd.to_datetime('today').date(),  # Default to today's date
        display_format='YYYY-MM-DD'
    ),
    # Div to display the selected date
    html.Div(id='output-container-date-picker'),
    # Div to display the Gantt chart
    dcc.Graph(id='gantt-chart')
])

# Callback to update the Gantt chart based on the selected date
@app.callback(
    Output('gantt-chart', 'figure'),
    Input('date-picker', 'date')
)
def update_gantt_chart(date):
    # Filter data for the selected date
    filtered_df = filter_data_for_day(events_df, date)
    # Generate Gantt chart
    gantt_chart = generate_gantt_chart(filtered_df)
    return gantt_chart

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import json

with open("data/events.json", "r", encoding='utf-8') as f:
    data = json.load(f)

len(data)
# Out:
# 2399

# %%
df = pd.DataFrame(data)
df['building'] = df['audience_number'].apply(lambda x: x.split()[1])
df.head()
# Out:
#                                                 name  \
# 0  Теория функций комплексного переменного(Горяйн...
# 1  Основы цифровой обработки сигналов/ст.преподав...
# 2  Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3  дополнительным главам общей физике ЛФИ Колдуно...
# 4  Кратные интегралы и теория поля /профессор Кар...
#
#                                          description  \
# 0  Теория функций комплексного переменного(Горяйн...
# 1  Основы цифровой обработки сигналов/ст.преподав...
# 2  Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3  дополнительным главам общей физике ЛФИ Колдуно...
# 4  Кратные интегралы и теория поля /профессор Кар...
#
#                                                 pair owner_user_wallet  \
# 0  {'name': 'Пара 1 1', 'time_slot_index': 1, 'we...              mipt
# 1  {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2  {'name': 'Пара 1 6', 'time_slot_index': 6, 'we...              mipt
# 3  {'name': 'Пара 1 7', 'time_slot_index': 7, 'we...              mipt
# 4  {'name': 'Пара 2 1', 'time_slot_index': 1, 'we...              mipt
#
#   audience_number building
# 0        250 None     None
# 1        250 None     None
# 2        250 None     None
# 3        250 None     None
# 4        250 None     None

# %%
df["pair"].apply(lambda d: d['name']).unique()
# Out:
# array(['Пара 1 1', 'Пара 1 3', 'Пара 1 6', 'Пара 1 7', 'Пара 2 1',
#        'Пара 2 2', 'Пара 2 3', 'Пара 2 4', 'Пара 2 7', 'Пара 2 8',
#        'Пара 3 2', 'Пара 3 3', 'Пара 3 4', 'Пара 3 5', 'Пара 3 7',
#        'Пара 4 1', 'Пара 4 3', 'Пара 4 5', 'Пара 4 8', 'Пара 4 6',
#        'Пара 4 7', 'Пара 5 1', 'Пара 5 2', 'Пара 6 5', 'Пара 5 3',
#        'Пара 5 4', 'Пара 5 5', 'Пара 5 7', 'Пара 6 1', 'Пара 6 2',
#        'Пара 6 3', 'Пара 6 4', 'Пара 6 7', 'Пара 1 2', 'Пара 1 4',
#        'Пара 2 5', 'Пара 2 6', 'Пара 3 6', 'Пара 3 8', 'Пара 4 2',
#        'Пара 4 4', 'Пара 5 6', 'Пара 5 8', 'Пара 6 6', 'Пара 7 1',
#        'Пара 7 2', 'Пара 7 3', 'Пара 7 4', 'Пара 7 5', 'Пара 7 6',
#        'Пара 3 1', 'Пара 6 8', 'Пара 1 8', 'Пара 7 7', 'Пара 7 8',
#        'Пара 1 5'], dtype=object)

# %%
df[df["pair"].apply(lambda d: d['name'] == 'Пара 1 6')]['pair'].apply(lambda d: d['description']).unique()
# Out:
# array(["Пара номер: Понедельник (6, '17:05', '18:30')"], dtype=object)

# %%
df['pair'].apply(lambda d: d['description']).unique()
# Out:
# array(["Пара номер: Понедельник (1, '09:00', '10:25')",
#        "Пара номер: Понедельник (3, '12:10', '13:55')",
#        "Пара номер: Понедельник (6, '17:05', '18:30')",
#        "Пара номер: Понедельник (7, '18:30', '20:00')",
#        "Пара номер: Вторник (1, '09:00', '10:25')",
#        "Пара номер: Вторник (2, '10:25', '12:10')",
#        "Пара номер: Вторник (3, '12:10', '13:55')",
#        "Пара номер: Вторник (4, '13:55', '15:30')",
#        "Пара номер: Вторник (7, '18:30', '20:00')",
#        "Пара номер: Вторник (8, '20:00', '22:00')",
#        "Пара номер: Среда (2, '10:25', '12:10')",
#        "Пара номер: Среда (3, '12:10', '13:55')",
#        "Пара номер: Среда (4, '13:55', '15:30')",
#        "Пара номер: Среда (5, '15:30', '17:05')",
#        "Пара номер: Среда (7, '18:30', '20:00')",
#        "Пара номер: Четверг (1, '09:00', '10:25')",
#        "Пара номер: Четверг (3, '12:10', '13:55')",
#        "Пара номер: Четверг (5, '15:30', '17:05')",
#        "Пара номер: Четверг (8, '20:00', '22:00')",
#        "Пара номер: Четверг (6, '17:05', '18:30')",
#        "Пара номер: Четверг (7, '18:30', '20:00')",
#        "Пара номер: Пятница (1, '09:00', '10:25')",
#        "Пара номер: Пятница (2, '10:25', '12:10')",
#        "Пара номер: Суббота (5, '15:30', '17:05')",
#        "Пара номер: Пятница (3, '12:10', '13:55')",
#        "Пара номер: Пятница (4, '13:55', '15:30')",
#        "Пара номер: Пятница (5, '15:30', '17:05')",
#        "Пара номер: Пятница (7, '18:30', '20:00')",
#        "Пара номер: Суббота (1, '09:00', '10:25')",
#        "Пара номер: Суббота (2, '10:25', '12:10')",
#        "Пара номер: Суббота (3, '12:10', '13:55')",
#        "Пара номер: Суббота (4, '13:55', '15:30')",
#        "Пара номер: Суббота (7, '18:30', '20:00')",
#        "Пара номер: Понедельник (2, '10:25', '12:10')",
#        "Пара номер: Понедельник (4, '13:55', '15:30')",
#        "Пара номер: Вторник (5, '15:30', '17:05')",
#        "Пара номер: Вторник (6, '17:05', '18:30')",
#        "Пара номер: Среда (6, '17:05', '18:30')",
#        "Пара номер: Среда (8, '20:00', '22:00')",
#        "Пара номер: Четверг (2, '10:25', '12:10')",
#        "Пара номер: Четверг (4, '13:55', '15:30')",
#        "Пара номер: Пятница (6, '17:05', '18:30')",
#        "Пара номер: Пятница (8, '20:00', '22:00')",
#        "Пара номер: Суббота (6, '17:05', '18:30')",
#        "Пара номер: Воскресенье (1, '09:00', '10:25')",
#        "Пара номер: Воскресенье (2, '10:25', '12:10')",
#        "Пара номер: Воскресенье (3, '12:10', '13:55')",
#        "Пара номер: Воскресенье (4, '13:55', '15:30')",
#        "Пара номер: Воскресенье (5, '15:30', '17:05')",
#        "Пара номер: Воскресенье (6, '17:05', '18:30')",
#        "Пара номер: Среда (1, '09:00', '10:25')",
#        "Пара номер: Суббота (8, '20:00', '22:00')",
#        "Пара номер: Понедельник (8, '20:00', '22:00')",
#        "Пара номер: Воскресенье (7, '18:30', '20:00')",
#        "Пара номер: Воскресенье (8, '20:00', '22:00')",
#        "Пара номер: Понедельник (5, '15:30', '17:05')"], dtype=object)

# %%
df[['day', 'time']] = df['pair'].apply(lambda d: pd.Series(d['name'].split()[1:]))
df
# Out:
#                                                    name  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 4     Кратные интегралы и теория поля /профессор Кар...
# ...                                                 ...
# 2394                           4к иностр тополог Елишев
# 2395                           4к иностр тополог Елишев
# 2396                    Общая физика 5 к. Рыбакова А.К.
# 2397                           1к иностр физика Мусин С
# 2398  с 14.09 по 14.12 Практикум по прикладной стати...
#
#                                             description  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 4     Кратные интегралы и теория поля /профессор Кар...
# ...                                                 ...
# 2394                           4к иностр тополог Елишев
# 2395                           4к иностр тополог Елишев
# 2396                    Общая физика 5 к. Рыбакова А.К.
# 2397                           1к иностр физика Мусин С
# 2398  с 14.09 по 14.12 Практикум по прикладной стати...
#
#                                                    pair owner_user_wallet  \
# 0     {'name': 'Пара 1 1', 'time_slot_index': 1, 'we...              mipt
# 1     {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2     {'name': 'Пара 1 6', 'time_slot_index': 6, 'we...              mipt
# 3     {'name': 'Пара 1 7', 'time_slot_index': 7, 'we...              mipt
# 4     {'name': 'Пара 2 1', 'time_slot_index': 1, 'we...              mipt
# ...                                                 ...               ...
# 2394  {'name': 'Пара 5 2', 'time_slot_index': 2, 'we...              mipt
# 2395  {'name': 'Пара 5 3', 'time_slot_index': 3, 'we...              mipt
# 2396  {'name': 'Пара 5 4', 'time_slot_index': 4, 'we...              mipt
# 2397  {'name': 'Пара 5 6', 'time_slot_index': 6, 'we...              mipt
# 2398  {'name': 'Пара 6 5', 'time_slot_index': 5, 'we...              mipt
#
#      audience_number building day time
# 0           250 None     None   1    1
# 1           250 None     None   1    3
# 2           250 None     None   1    6
# 3           250 None     None   1    7
# 4           250 None     None   2    1
# ...              ...      ...  ..  ...
# 2394         202 УПМ      УПМ   5    2
# 2395         202 УПМ      УПМ   5    3
# 2396         202 УПМ      УПМ   5    4
# 2397         202 УПМ      УПМ   5    6
# 2398         202 УПМ      УПМ   6    5
#
# [2399 rows x 8 columns]

# %%
WEEKDAYS = {
    "1": "Monday",
    "2": "Tuesday",
    "3": "Wednesday",
    "4": "Thursday",
    "5": "Friday",
    "6": "Saturday",
    "7": "Sunday",
}

TIME_SLOTS = {
    "1": ("09:00", "10:25"),
    "2": ("10:45", "12:10"),
    "3": ("12:20", "13:45"),
    "4": ("13:55", "15:20"),
    "5": ("15:30", "16:55"),
    "6": ("17:05", "18:30"),
    "7": ("18:35", "20:00"),
    "8": ("20:00", "22:00"),
}

# %%
df[['time_start', 'time_finish']] = df['time'].apply(lambda x: pd.Series(TIME_SLOTS[x]))
df['weekday'] = df['day'].map(WEEKDAYS)
df
# Out:
#                                                    name  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 4     Кратные интегралы и теория поля /профессор Кар...
# ...                                                 ...
# 2394                           4к иностр тополог Елишев
# 2395                           4к иностр тополог Елишев
# 2396                    Общая физика 5 к. Рыбакова А.К.
# 2397                           1к иностр физика Мусин С
# 2398  с 14.09 по 14.12 Практикум по прикладной стати...
#
#                                             description  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 4     Кратные интегралы и теория поля /профессор Кар...
# ...                                                 ...
# 2394                           4к иностр тополог Елишев
# 2395                           4к иностр тополог Елишев
# 2396                    Общая физика 5 к. Рыбакова А.К.
# 2397                           1к иностр физика Мусин С
# 2398  с 14.09 по 14.12 Практикум по прикладной стати...
#
#                                                    pair owner_user_wallet  \
# 0     {'name': 'Пара 1 1', 'time_slot_index': 1, 'we...              mipt
# 1     {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2     {'name': 'Пара 1 6', 'time_slot_index': 6, 'we...              mipt
# 3     {'name': 'Пара 1 7', 'time_slot_index': 7, 'we...              mipt
# 4     {'name': 'Пара 2 1', 'time_slot_index': 1, 'we...              mipt
# ...                                                 ...               ...
# 2394  {'name': 'Пара 5 2', 'time_slot_index': 2, 'we...              mipt
# 2395  {'name': 'Пара 5 3', 'time_slot_index': 3, 'we...              mipt
# 2396  {'name': 'Пара 5 4', 'time_slot_index': 4, 'we...              mipt
# 2397  {'name': 'Пара 5 6', 'time_slot_index': 6, 'we...              mipt
# 2398  {'name': 'Пара 6 5', 'time_slot_index': 5, 'we...              mipt
#
#      audience_number building day time time_start time_finish   weekday
# 0           250 None     None   1    1      09:00       10:25    Monday
# 1           250 None     None   1    3      12:20       13:45    Monday
# 2           250 None     None   1    6      17:05       18:30    Monday
# 3           250 None     None   1    7      18:35       20:00    Monday
# 4           250 None     None   2    1      09:00       10:25   Tuesday
# ...              ...      ...  ..  ...        ...         ...       ...
# 2394         202 УПМ      УПМ   5    2      10:45       12:10    Friday
# 2395         202 УПМ      УПМ   5    3      12:20       13:45    Friday
# 2396         202 УПМ      УПМ   5    4      13:55       15:20    Friday
# 2397         202 УПМ      УПМ   5    6      17:05       18:30    Friday
# 2398         202 УПМ      УПМ   6    5      15:30       16:55  Saturday
#
# [2399 rows x 11 columns]

# %%
off = df[df['name'] != df['description']].sample(1)
off
# Out:
#                                                   name  \
# 729  А.К. 3: 2 из 4: Эффективные алгоритмы/ ст.преп...
#
#                                            description  \
# 729  А.К. 3: 2 из 4: Эффективные алгоритмы/ ст.преп...
#
#                                                   pair owner_user_wallet  \
# 729  {'name': 'Пара 5 7', 'time_slot_index': 7, 'we...              mipt
#
#     audience_number building day time time_start time_finish weekday
# 729      5.18 Цифра    Цифра   5    7      18:35       20:00  Friday

# %%
import datetime as dtt

# %%
selected_date = dtt.datetime.strptime("2024-11-18", '%Y-%m-%d')
weekday = str(selected_date.weekday()+1)

# %%
filtered_df = df[(df['day'] == weekday)]
filtered_df
# Out:
#                                                    name  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 34    Введение в математический анализ / профессор З...
# ...                                                 ...
# 2328  ЛФИ факультатив. Основы моделирования физическ...
# 2351  6 к иностр Введение в физику плазмы, Введение ...
# 2352  6 к иностр Введение в физику плазмы, Введение ...
# 2353  6 к иностр Введение в физику плазмы, Введение ...
# 2354  6 к иностр Введение в физику плазмы, Введение ...
#
#                                             description  \
# 0     Теория функций комплексного переменного(Горяйн...
# 1     Основы цифровой обработки сигналов/ст.преподав...
# 2     Безопасность жизнедеятельности / ФПМИ(ФУПМ), И...
# 3     дополнительным главам общей физике ЛФИ Колдуно...
# 34    Введение в математический анализ / профессор З...
# ...                                                 ...
# 2328  ЛФИ факультатив. Основы моделирования физическ...
# 2351  6 к иностр Введение в физику плазмы, Введение ...
# 2352  6 к иностр Введение в физику плазмы, Введение ...
# 2353  6 к иностр Введение в физику плазмы, Введение ...
# 2354  6 к иностр Введение в физику плазмы, Введение ...
#
#                                                    pair owner_user_wallet  \
# 0     {'name': 'Пара 1 1', 'time_slot_index': 1, 'we...              mipt
# 1     {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2     {'name': 'Пара 1 6', 'time_slot_index': 6, 'we...              mipt
# 3     {'name': 'Пара 1 7', 'time_slot_index': 7, 'we...              mipt
# 34    {'name': 'Пара 1 2', 'time_slot_index': 2, 'we...              mipt
# ...                                                 ...               ...
# 2328  {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2351  {'name': 'Пара 1 1', 'time_slot_index': 1, 'we...              mipt
# 2352  {'name': 'Пара 1 2', 'time_slot_index': 2, 'we...              mipt
# 2353  {'name': 'Пара 1 3', 'time_slot_index': 3, 'we...              mipt
# 2354  {'name': 'Пара 1 4', 'time_slot_index': 4, 'we...              mipt
#
#      audience_number building day time time_start time_finish weekday
# 0           250 None     None   1    1      09:00       10:25  Monday
# 1           250 None     None   1    3      12:20       13:45  Monday
# 2           250 None     None   1    6      17:05       18:30  Monday
# 3           250 None     None   1    7      18:35       20:00  Monday
# 34          300 None     None   1    2      10:45       12:10  Monday
# ...              ...      ...  ..  ...        ...         ...     ...
# 2328         203 УПМ      УПМ   1    3      12:20       13:45  Monday
# 2351         204 УПМ      УПМ   1    1      09:00       10:25  Monday
# 2352         204 УПМ      УПМ   1    2      10:45       12:10  Monday
# 2353         204 УПМ      УПМ   1    3      12:20       13:45  Monday
# 2354         204 УПМ      УПМ   1    4      13:55       15:20  Monday
#
# [240 rows x 11 columns]

# %%
sorted(df["room"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Redencon\Documents\PyScripts\Roomba\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'room'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sorted(df["room"].unique())
#
# File c:\Users\Redencon\Documents\PyScripts\Roomba\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Redencon\Documents\PyScripts\Roomba\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'room'

# %%
df['building'].unique()
# Out:
# array(['None', 'УПМ', 'Квант', 'Цифра', 'КПМ', 'ГК', 'БК'], dtype=object)
